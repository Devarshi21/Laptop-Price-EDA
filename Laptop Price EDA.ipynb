# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r"C:\Users\bobad\OneDrive\Desktop\project\laptopPrice.csv"
df = pd.read_csv(path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    object
#  17  Number of Ratings  823 non-null    int64
#  18  Number of Reviews  823 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 122.3+ KB

# %%
df.isna().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 21

# %%
df = df.drop_duplicates(keep = 'first')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              802 non-null    object
#  1   processor_brand    802 non-null    object
#  2   processor_name     802 non-null    object
#  3   processor_gnrtn    802 non-null    object
#  4   ram_gb             802 non-null    object
#  5   ram_type           802 non-null    object
#  6   ssd                802 non-null    object
#  7   hdd                802 non-null    object
#  8   os                 802 non-null    object
#  9   os_bit             802 non-null    object
#  10  graphic_card_gb    802 non-null    object
#  11  weight             802 non-null    object
#  12  warranty           802 non-null    object
#  13  Touchscreen        802 non-null    object
#  14  msoffice           802 non-null    object
#  15  Price              802 non-null    int64
#  16  rating             802 non-null    object
#  17  Number of Ratings  802 non-null    int64
#  18  Number of Reviews  802 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 125.3+ KB

# %% [markdown]
# ### Cat & con seperation

# %%
cat = list(df.columns[df.dtypes=='object'])
cat
# Out:
# ['brand',
#  'processor_brand',
#  'processor_name',
#  'processor_gnrtn',
#  'ram_gb',
#  'ram_type',
#  'ssd',
#  'hdd',
#  'os',
#  'os_bit',
#  'graphic_card_gb',
#  'weight',
#  'warranty',
#  'Touchscreen',
#  'msoffice',
#  'rating']

# %%
con = list(df.columns[df.dtypes!='object'])
con
# Out:
# ['Price', 'Number of Ratings', 'Number of Reviews']

# %%
df[cat].describe().T
# Out:
#                 count unique      top freq
# brand             802      8     ASUS  243
# processor_brand   802      3    Intel  594
# processor_name    802     11  Core i5  284
# processor_gnrtn   802      8     11th  328
# ram_gb            802      4     8 GB  404
# ram_type          802      6     DDR4  690
# ssd               802      7   512 GB  389
# hdd               802      4     0 GB  602
# os                802      3  Windows  763
# os_bit            802      2   64-bit  693
# graphic_card_gb   802      5     0 GB  557
# weight            802      3   Casual  509
# warranty          802      4   1 year  498
# Touchscreen       802      2       No  706
# msoffice          802      2       No  522
# rating            802      5  4 stars  437

# %%
df[con].describe().T
# Out:
#                    count          mean           std      min      25%  \
# Price              802.0  76625.543641  45232.984422  16990.0  45990.0
# Number of Ratings  802.0    299.844140   1001.784420      0.0      0.0
# Number of Reviews  802.0     36.089776    118.313553      0.0      0.0
#
#                        50%       75%       max
# Price              63990.0  89525.00  441990.0
# Number of Ratings     17.0    140.25   15279.0
# Number of Reviews      2.0     18.00    1947.0

# %% [markdown]
# ### Data visualization

# %%
for i in cat:
    plt.figure(figsize=(12,4))
    sns.countplot(data=df, x= i)
    plt.show()

# %%
for i in con:
    plt.figure(figsize=(12,4))
    sns.histplot(data=df, x= i)
    plt.show()

# %%
plt.figure(figsize=(12,4))
sns.boxplot(data=df, x='brand', y='Number of Ratings')
# Out:
# <Axes: xlabel='brand', ylabel='Number of Ratings'>

# %%
df['rating'].value_counts()
# Out:
# rating
# 4 stars    437
# 3 stars    338
# 5 stars     16
# 2 stars      9
# 1 star       2
# Name: count, dtype: int64

# %%
df[cat].columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'rating'],
#       dtype='object')

# %%
df.groupby(by=['brand', 'rating']).plot(type='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.groupby(by=['brand', 'rating']).plot(type='bar')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:723, in GroupByPlot.__call__(self, *args, **kwargs)
#     720     return self.plot(*args, **kwargs)
#     722 f.__name__ = "plot"
# --> 723 return self._groupby._python_apply_general(f, self._groupby._selected_obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1819, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1784 @final
#    1785 def _python_apply_general(
#    1786     self,
#    (...)
#    1791     is_agg: bool = False,
#    1792 ) -> NDFrameT:
#    1793     """
#    1794     Apply function f in python space
#    1795
#    (...)
#    1817         data after applying f
#    1818     """
# -> 1819     values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1820     if not_indexed_same is None:
#    1821         not_indexed_same = mutated
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:911, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     909 # group might be modified
#     910 group_axes = group.axes
# --> 911 res = f(group)
#     912 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     913     mutated = True
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:720, in GroupByPlot.__call__.<locals>.f(self)
#     719 def f(self):
# --> 720     return self.plot(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:453, in MPLPlot.generate(self)
#     451 self._compute_plot_data()
#     452 self._setup_subplots()
# --> 453 self._make_plot()
#     454 self._add_table()
#     455 self._make_legend()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1392, in LinePlot._make_plot(self)
#    1389 label = self._mark_right_label(label, index=i)
#    1390 kwds["label"] = label
# -> 1392 newlines = plotf(
#    1393     ax,
#    1394     x,
#    1395     y,
#    1396     style=style,
#    1397     column_num=i,
#    1398     stacking_id=stacking_id,
#    1399     is_errorbar=is_errorbar,
#    1400     **kwds,
#    1401 )
#    1402 self._append_legend_handles_labels(newlines[0], label)
#    1404 if self._is_ts_plot():
#    1405     # reset of xlim should be used for ts data
#    1406     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1421, in LinePlot._plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1419     cls._initialize_stacker(ax, stacking_id, len(y))
#    1420 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1421 lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1422 cls._update_stacker(ax, stacking_id, y)
#    1423 return lines
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\converter.py:97, in register_pandas_matplotlib_converters.<locals>.wrapper(*args, **kwargs)
#      94 @functools.wraps(func)
#      95 def wrapper(*args, **kwargs):
#      96     with pandas_converters():
# ---> 97         return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:891, in MPLPlot._plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     888 else:
#     889     # prevent style kwarg from going to errorbar, where it is unsupported
#     890     args = (x, y, style) if style is not None else (x, y)
# --> 891     return ax.plot(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:539, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:539, in <listcomp>(.0)
#     537     return list(result)
#     538 else:
# --> 539     return [l[0] for l in result]
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:532, in <genexpr>(.0)
#     529 else:
#     530     labels = [label] * n_datasets
# --> 532 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     533                       {**kwargs, 'label': label})
#     534           for j, label in enumerate(labels))
#     536 if return_kwargs:
#     537     return list(result)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:346, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     344 default_dict = self._getdefaults(set(), kw)
#     345 self._setdefaults(default_dict, kw)
# --> 346 seg = mlines.Line2D(x, y, **kw)
#     347 return seg, kw
#
# File ~\anaconda3\Lib\site-packages\matplotlib\lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'type'
